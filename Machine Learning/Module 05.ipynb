# %%
print("Tanvir")
# Out:
# Tanvir

# %%
print("Tanvirs")
# Out:
# Tanvirs

# %%
# !nvidia-smi
# Out:
# Mon Nov 17 18:44:21 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.80                 Driver Version: 581.80         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   46C    P8              2W /   50W |     716MiB /   6141MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'h':[150,160,170,185,190],
                   'w':[50,58,70,80,90]})
df
# Out:
#      h   w
# 0  150  50
# 1  160  58
# 2  170  70
# 3  185  80
# 4  190  90

# %%
df.plot(kind='bar')
plt.title("Z scaling Features")
plt.xlabel("Index"); 
plt.ylabel('z value')
plt.show()
